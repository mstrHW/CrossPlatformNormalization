# %% [markdown]
# <h1>Iteration 1 : Plot T-SNE</h1>

# %%
import csv
import numpy as np
import pandas as pd
import sys
sys.path.append("../") 

import os
from module.data_processing.read_data import *
import json

ROOT_DIR = '/home/aonishchuk/'
DATA_DIR = os.path.join(ROOT_DIR, 'data')
IMAGES_DIR = os.path.join(ROOT_DIR, 'images')

illu_file = os.path.join(DATA_DIR, 'illu_rawnorm.csv')
genes_file = os.path.join(DATA_DIR, 'illu_genes.pkl')
landmarks_file = os.path.join(DATA_DIR, 'landmarks.txt')
kkochetov_model_params_file = os.path.join(DATA_DIR, 'archs.json')
best_genes_file = os.path.join(DATA_DIR, 'illu_dfs.pkl')

# %% [markdown]
# <h3>Read data</h3>

# %%
data = read_csv(illu_file, None)
best_genes = read_genes(best_genes_file)[:1000]

# %% [markdown]
# <h3>T-SNE</h3>

# %%
from sklearn.manifold import TSNE

def calculate_tsne(data):
    tsne_results = TSNE(n_components=2).fit_transform(data)
    return tsne_results

# %%
tsne = calculate_tsne(data[best_genes])

# %%
import matplotlib.pyplot as plt
import seaborn as sns


def plot_tsne_seaborn(tsne, target_column, title=None):
    df_subset = pd.DataFrame()
    df_subset['tsne-2d-one'] = tsne[:, 0]
    df_subset['tsne-2d-two'] = tsne[:, 1]

    plt.figure(figsize=(16, 10))
    sns.scatterplot(
        x="tsne-2d-one", y="tsne-2d-two",
        hue=target_column,
        palette=sns.color_palette("hls", target_column.nunique()),
        data=df_subset,
        legend="full",
        alpha=0.3
    )

    if title is not None:
        image_name = os.path.join(IMAGES_DIR, '{}.png'.format(title))
        plt.savefig(image_name)

# %%
target_columns = ['GEO', 'Tissue', 'Age_group', 'Sex']
for column in target_columns:
    plot_tsne_seaborn(tsne, data[column], 'tsne_{}'.format(column.lower()))

# %%
from module.data_processing.data_generating_cases import processing_conveyor

processing_sequence = {
    'load_data': dict(
        features_count=1000,
        rows_count=None,
    ),
    'filter_data': dict(
        filtered_column='Tissue',
        using_values='Whole blood',
    ),
    'apply_logarithm': dict(
        shift=3,
    ),
    'normalization': dict(
        method='series',
    ),
}

data_holder = processing_conveyor(processing_sequence)
# Out:
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_holder.processing_sequence = {
    'load_data': dict(
        features_count=1000,
        rows_count=None,
    ),
}

data_holder.processed_data = data_holder.parse_sequence()
tsne = calculate_tsne(data_holder.processed_data[data_holder.best_genes])
plot_tsne_seaborn(tsne, data_holder.processed_data['GEO'])

# %%
data_holder.processing_sequence = {
    'load_data': dict(
        features_count=1000,
        rows_count=None,
    ),
    'filter_data': dict(
        filtered_column='Tissue',
        using_values='Whole blood',
    ),
}

data_holder.processed_data = data_holder.parse_sequence()
tsne = calculate_tsne(data_holder.processed_data[data_holder.best_genes])
plot_tsne_seaborn(tsne, data_holder.processed_data['GEO'])

# %%
data_holder.processing_sequence = {
    'load_data': dict(
        features_count=1000,
        rows_count=None,
    ),
    'filter_data': dict(
        filtered_column='Tissue',
        using_values='Whole blood',
    ),
    'normalization': dict(
        method='default',
    ),
}

data_holder.processed_data = data_holder.parse_sequence()
tsne = calculate_tsne(data_holder.processed_data[data_holder.best_genes])
plot_tsne_seaborn(tsne, data_holder.processed_data['GEO'])
# Out:
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_holder.processing_sequence = {
    'load_data': dict(
        features_count=1000,
        rows_count=None,
    ),
    'filter_data': dict(
        filtered_column='Tissue',
        using_values='Whole blood',
    ),
    'normalization': dict(
        method='series',
    ),
}

data_holder.processed_data = data_holder.parse_sequence()
tsne = calculate_tsne(data_holder.processed_data[data_holder.best_genes])
plot_tsne_seaborn(tsne, data_holder.processed_data['GEO'])
# Out:
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_holder.processing_sequence = {
    'load_data': dict(
        features_count=1000,
        rows_count=None,
    ),
    'filter_data': dict(
        filtered_column='Tissue',
        using_values='Whole blood',
    ),
    'apply_logarithm': dict(
        shift=3,
    ),
    'normalization': dict(
        method='default',
    ),
}

data_holder.processed_data = data_holder.parse_sequence()
tsne = calculate_tsne(data_holder.processed_data[data_holder.best_genes])
plot_tsne_seaborn(tsne, data_holder.processed_data['GEO'])
# Out:
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_holder.processing_sequence = {
    'load_data': dict(
        features_count=1000,
        rows_count=None,
    ),
    'filter_data': dict(
        filtered_column='Tissue',
        using_values='Whole blood',
    ),
    'apply_logarithm': dict(
        shift=3,
    ),
    'normalization': dict(
        method='series',
    ),
}

data_holder.processed_data = data_holder.parse_sequence()
tsne = calculate_tsne(data_holder.processed_data[data_holder.best_genes])
plot_tsne_seaborn(tsne, data_holder.processed_data['GEO'])
# Out:
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_holder.processing_sequence = {
    'load_data': dict(
        features_count=1000,
        rows_count=None,
    ),
    'filter_data': dict(
        filtered_column='Tissue',
        using_values='Whole blood',
    ),
    'normalization': dict(
        method='series',
    ),
    'apply_logarithm': dict(
        shift=3,
    ),
}

data_holder.processed_data = data_holder.parse_sequence()
tsne = calculate_tsne(data_holder.processed_data[data_holder.best_genes])
plot_tsne_seaborn(tsne, data_holder.processed_data['GEO'])
# Out:
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
from module.data_processing.data_processing import add_gaussian_noise

generated_data = np.zeros(shape=(1, data_holder.processed_data.shape[1]))
for generated_batch in add_gaussian_noise(data_holder.processed_data, 128, 0.5):
    generated_data = np.concatenate((generated_data, generated_batch), axis=0)
generated_data = generated_data[1:]

tsne = calculate_tsne(generated_data[data_holder.best_genes])
plot_tsne_seaborn(tsne, generated_data['GEO'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: must be str, not float
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1032             with np.errstate(all='ignore'):
# -> 1033                 return na_op(lvalues, rvalues)
#    1034         except Exception:
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1017                 mask = notna(x) & notna(y)
# -> 1018                 result[mask] = op(x[mask], com._values_from_object(y[mask]))
#    1019             else:
#
# TypeError: must be str, not float
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1496         try:
# -> 1497             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1498         except TypeError:
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1068
# -> 1069         result = safe_na_op(lvalues, rvalues)
#    1070         return construct_result(left, result,
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-2c4956580e63> in <module>
#       2
#       3 generated_data = np.zeros(shape=(1, data_holder.processed_data.shape[1]))
# ----> 4 for generated_batch in add_gaussian_noise(data_holder.processed_data, 128, 0.5):
#       5     generated_data = np.concatenate((generated_data, generated_batch), axis=0)
#       6 generated_data = generated_data[1:]
#
# ~\Documents\GitHub\CrossPlatformNormalization\CrossPlatformNormalization\module\data_processing\data_processing.py in add_gaussian_noise(data, batch_size, noise_probability_for_gene)
#      84     noise = gaussian_noise(batch_shape, 0.5, 0.5)
#      85     data = data.where(noising_flags, data + noise)
# ---> 86     return data
#      87
#      88
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    1548
#    1549         if isinstance(other, ABCDataFrame):  # Another DataFrame
# -> 1550             return self._combine_frame(other, na_op, fill_value, level)
#    1551         elif isinstance(other, ABCSeries):
#    1552             return _combine_series_frame(self, other, na_op,
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in _combine_frame(self, other, func, fill_value, level)
#    4740                 # unique columns
#    4741                 result = {col: _arith_op(this[col], other[col])
# -> 4742                           for col in this}
#    4743                 result = self._constructor(result, index=new_index,
#    4744                                            columns=new_columns, copy=False)
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in <dictcomp>(.0)
#    4740                 # unique columns
#    4741                 result = {col: _arith_op(this[col], other[col])
# -> 4742                           for col in this}
#    4743                 result = self._constructor(result, index=new_index,
#    4744                                            columns=new_columns, copy=False)
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in _arith_op(left, right)
#    4733             # left._binop(right, func, fill_value=fill_value)
#    4734             left, right = ops.fill_binop(left, right, fill_value)
# -> 4735             return func(left, right)
#    4736
#    4737         if this._is_mixed_type or other._is_mixed_type:
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1514                 if xrav.size:
#    1515                     with np.errstate(all='ignore'):
# -> 1516                         result[mask] = op(xrav, yrav)
#    1517
#    1518             elif isinstance(x, np.ndarray):
#
# TypeError: must be str, not float

# %%
from module.data_processing.data_generator import DistanceNoiseGenerator


data_holder.processing_sequence = {
    'load_data': dict(
        features_count=1000,
        rows_count=None,
    ),
    'filter_data': dict(
        filtered_column='Tissue',
        using_values='Whole blood',
    ),
    'normalization': dict(
        method='series',
    ),
    'apply_logarithm': dict(
        shift=3,
    ),
}

processed_data = data_holder.parse_sequence()
# Out:
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
from module.data_processing.data_processing import get_batches


noise_probability = 0.25
batch_size = 128

ref_batch_name = processed_data['GEO'].value_counts().keys()[0]
ref_mask = processed_data['GEO'] == ref_batch_name
ref_data = processed_data[ref_mask]
corrupt_data = processed_data[~ref_mask]

noised_batches_generator = DistanceNoiseGenerator(
    ref_data,
    corrupt_data,
    data_holder.best_genes,
    'test',
    noise_probability,
)

generated_data = np.zeros(shape=(1, data_holder.processed_data.shape[1]))
for batch in get_batches(corrupt_data, batch_size):
    generated_batch = batch
    generated_batch.loc[:, data_holder.best_genes] = noised_batches_generator.data_generation(batch[data_holder.best_genes].values)
    #     generated_data = np.concatenate((generated_data, generated_batch), axis=0)
    generated_data = pd.concat([generated_data, generated_batch], ignore_index=True)
generated_data = generated_data.iloc[1:]
# Out:
# 14it [00:01,  7.47it/s]
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-3bdbf918f406> in <module>
#      21 for batch in get_batches(corrupt_data, batch_size):
#      22     generated_batch = batch
# ---> 23     generated_batch.loc[:, data_holder.best_genes] = noised_batches_generator.data_generation(batch[data_holder.best_genes].values)
#      24     generated_data = np.concatenate((generated_data, generated_batch), axis=0)
#      25 generated_data = generated_data[1:]
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     187             key = com._apply_if_callable(key, self.obj)
#     188         indexer = self._get_setitem_indexer(key)
# --> 189         self._setitem_with_indexer(indexer, value)
#     190
#     191     def _validate_key(self, key, axis):
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     594
#     595                         # setting with a list, recoerces
# --> 596                         setter(item, value[:, i].tolist())
#     597
#     598                 # we have an equal len list/ndarray
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in setter(item, v)
#     541
#     542                 # reset the sliced object if unique
# --> 543                 self.obj[item] = s
#     544
#     545             def can_do_equal_len():
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3199         # value exception to occur first
#    3200         if len(self):
# -> 3201             self._check_setitem_copy()
#    3202
#    3203     def insert(self, loc, column, value, allow_duplicates=False):
#
# c:\users\hwer\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    2672             try:
#    2673                 gc.collect(2)
# -> 2674                 if not gc.get_referents(self._is_copy()):
#    2675                     self._is_copy = None
#    2676                     return
#
# KeyboardInterrupt:
